# %%
import networkx as nx

graph = open("outputs/graph.txt", "r")
n, m = map(int, graph.readline().strip().split(' '))

G = nx.Graph()

for _ in range(m):
    a, b, w = map(int, graph.readline().strip().split(' '))
    G.add_edge(a, b, weight=w)

nx.draw_shell(G, with_labels=True, font_weight='bold')
pos=nx.shell_layout(G)
edge_labels=dict([((u,v,),d['weight']) for u,v,d in G.edges(data=True)])
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels)
# Out:
# {(0, 2): Text(-0.7499999552965164, -0.4330127676341178, '832'),
#  (0, 3): Text(-0.2500000447034836, -0.4330127676341178, '743'),
#  (0, 4): Text(0.0, 4.371138828673793e-08, '428'),
#  (0, 5): Text(-0.2500001937150955, 0.43301276961830837, '528'),
#  (2, 4): Text(0.2500000447034836, -0.4330126364999529, '1000'),
#  (3, 4): Text(0.7499999552965164, -0.4330126364999529, '121'),
#  (4, 1): Text(0.24999988079071045, 0.4330127219385389, '148'),
#  (5, 1): Text(-3.129243850708008e-07, 0.866025447845459, '54')}

# %%
import networkx as nx

graph = open("outputs/kruskal.txt", "r")

G = nx.Graph()

for _ in graph.readlines():
    a, b, w = map(int, _.strip().split(' '))
    G.add_edge(a, b, weight=w)

nx.draw_shell(G, with_labels=True, font_weight='bold')
pos=nx.shell_layout(G)
edge_labels=dict([((u,v,),d['weight']) for u,v,d in G.edges(data=True)])
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels)
# Out:
# {(1, 5): Text(-0.7499999552965164, -0.4330127676341178, '54'),
#  (1, 4): Text(0.0, 4.371138828673793e-08, '148'),
#  (3, 4): Text(0.7499999552965164, -0.4330126364999529, '121'),
#  (4, 0): Text(0.7499998062849045, 0.43301290075247323, '428'),
#  (0, 2): Text(-3.129243850708008e-07, 0.866025447845459, '832')}

# %%
import networkx as nx

graph = open("outputs/prim.txt", "r")

G = nx.Graph()

for _ in graph.readlines():
    a, b, w = map(int, _.strip().split(' '))
    G.add_edge(a, b, weight=w)

nx.draw_shell(G, with_labels=True, font_weight='bold')
pos=nx.shell_layout(G)
edge_labels=dict([((u,v,),d['weight']) for u,v,d in G.edges(data=True)])
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels)
# Out:
# {(0, 4): Text(-0.7499999552965164, -0.4330127676341178, '428'),
#  (0, 2): Text(-0.7500001192092896, 0.43301259080437404, '832'),
#  (4, 3): Text(0.0, -0.866025447845459, '121'),
#  (4, 1): Text(0.2500000447034836, -0.4330126364999529, '148'),
#  (1, 5): Text(0.7499998062849045, 0.43301290075247323, '54')}

# %%
import networkx as nx

graph = open("outputs/true.txt", "r")

G = nx.Graph()

for _ in graph.readlines():
    a, b, w = map(int, _.strip().split(' '))
    G.add_edge(a, b, weight=w)

nx.draw_shell(G, with_labels=True, font_weight='bold')
pos=nx.shell_layout(G)
edge_labels=dict([((u,v,),d['weight']) for u,v,d in G.edges(data=True)])
nx.draw_networkx_edge_labels(G,pos,edge_labels=edge_labels)
# Out:
# {(0, 2): Text(-0.7499999552965164, -0.4330127676341178, '832'),
#  (0, 4): Text(-0.2500000447034836, -0.4330127676341178, '428'),
#  (4, 1): Text(0.7499999552965164, -0.4330126364999529, '148'),
#  (4, 3): Text(-1.6391277313232422e-07, -8.940696716308594e-08, '121'),
#  (1, 5): Text(0.7499998062849045, 0.43301290075247323, '54')}

# %% [markdown]
# <b>

# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")


df = pd.read_csv("outputs/results.txt")

# %%
df
# Out:
#        n        m  kruskal_time  prim_time  true_time
# 0     10        9           0.0        0.0        0.0
# 1     10       18           0.0        0.0        0.0
# 2     10       27           0.0        0.0        0.0
# 3     10       36           0.0        0.0        0.0
# 4     10       45           0.0        0.0        0.0
# 5     10       54           0.0        0.0        0.0
# 6    100       99           0.0        0.0        0.0
# 7    100     1089           0.0        0.0        1.8
# 8    100     2079           0.0        0.0        4.0
# 9    100     3069           0.0        0.0        6.0
# 10   100     4059           0.6        0.4        8.6
# 11   100     5049           1.0        0.4       10.6
# 12   200      199           0.0        0.0        0.0
# 13   200     4179           0.8        0.6       12.2
# 14   200     8159           2.0        1.2       24.2
# 15   200    12139           3.0        2.0       35.6
# ...

# %% [markdown]
# ## Kruskal algorithm

# %%
for n in [10, 100, 200, 500, 1000, 2000, 3000]:
    g = sns.lmplot(x="m", y="kruskal_time", hue="n", col="n",
                   data=df[df['n'] == n], col_wrap=3, height=5, aspect=1, order=2)

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams.update({'font.size': 14})

plt.figure(figsize=(20, 10))

for i in range(0, 6):
    data = df.groupby('n').apply(lambda x: x.iloc[i])
#     data = data[:3]
#     print(data)
    sns.regplot(data['n'], data['kruskal_time'], order=2, line_kws={'linewidth': 5}, scatter_kws={'s': 100}, label=str(i) +'*p')

plt.legend()
plt.show()

# %% [markdown]
# ## Prim algorithm

# %%
for n in [10, 100, 200, 500, 1000, 2000, 3000]:
    g = sns.lmplot(x="m", y="prim_time", hue="n", col="n",
                   data=df[df['n'] == n], col_wrap=3, height=5, aspect=1, order=2)

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams.update({'font.size': 14})

plt.figure(figsize=(20, 10))

for i in range(0, 6):
    data = df.groupby('n').apply(lambda x: x.iloc[i])
    data = data[:3]
#     print(data)
    sns.regplot(data['n'], data['prim_time'], order=2, line_kws={'linewidth': 5}, scatter_kws={'s': 100}, label=str(i) +'*p')

plt.legend()
plt.show()

# %% [markdown]
# <b>
